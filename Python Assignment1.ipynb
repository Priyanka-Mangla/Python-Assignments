# %% [markdown]
# **PYTHON ASSIGNMENT 1**

# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *         ------ Expression
#
# 'hello'   ------ String
#
# -87.8     ------ Value
#
# -         ------ Expression
#
# /         ------ Expression
#
# +         ------ Expression
#
# 6         ------ Value

# %% [markdown]
# 2. What is the difference between string and variable?
#
# String: String can be written in quotes such: "apple", 'apple'
#
# Variable: It is the thing in which we can store data just like a container.

# %% [markdown]
# 3. Describe three different data types.
#
# List: It is used for storing multiple data items in a single variable.
#
# Integer: It can store only numerical values.
#
# Float: It can store only floating values such as 233.33, 22.2, etc.
#
# String: A string is a collection of one or more characters put in a single quote, double-quote or triple quote such as "Hello", "2456789".

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
#
# An expression is a combination of values, variables, operators, and calls to functions e.g a = 2 + 3  . Expressions need to be evaluated the values or represent the result on the screen..

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Expression: Something which evaluates to a value. Example: 1+2/x
#
# Statement: A line of code which does something. Example: GOTO 100

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1
#
# Sol: It gives 23 as execution code.

# %%
bacon = 22

bacon + 1
# Out:
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam' * 3
#
# Sol: 'spamspamspam'
#
#      'spamspamspam'

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#  Variable names cannot begin with a number. eggs is a valid variable and 100 causes an error because it is a integer.

# %%
eggs = 20
eggs
# Out:
# 20

# %%
100 = 20
# Out:
#   File "<ipython-input-6-06d90a1f05e3>", line 1
#     100 = 20
#             ^
# SyntaxError: can't assign to literal

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# str()
#
# int()
#
# float()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %%
'I have eaten ' + '99' + ' burritos'
# Out:
# 'I have eaten 99 burritos'
